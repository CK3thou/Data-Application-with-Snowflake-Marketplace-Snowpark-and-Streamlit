# %%
from snowflake.snowpark.session import Session
from snowflake.snowpark.types import IntegerType, FloatType
from snowflake.snowpark.functions import avg, sum, col, udf, call_udf, call_builtin, year, month
import streamlit as st
import pandas as pd
from datetime import date

# scikit-learn (install: pip install -U scikit-learn)
from sklearn.linear_model import LinearRegression

# %%
# Session
connection_parameters = {
   "account": "zburrql-mb49734",
   "user": "CK3000",
   "password": "-P3n5ac()la#1",
   "warehouse": "compute_wh",
   "role": "accountadmin",
   "database": "summit_hol",
   "schema": "CYBERSYN"
}
session = Session.builder.configs(connection_parameters).create()
# test if we have a connection
session.sql("select current_account() acct, current_warehouse() wh, current_database() db, current_schema() schema, current_version() v").show()
# Out:
# ---------------------------------------------------
# |"ACCT"   |"WH"        |"DB"  |"SCHEMA"  |"V"     |
# ---------------------------------------------------
# |VW65405  |COMPUTE_WH  |NULL  |NULL      |8.11.4  |
# ---------------------------------------------------

# %%
# SQL queries to explore the data

# What financial data is available as a time-series from FRED?
session.sql("SELECT DISTINCT variable_name FROM FINANCIAL__ECONOMIC_ESSENTIALS.CYBERSYN.FINANCIAL_FRED_TIMESERIES").show()

# What is the size of all the time-series data?
session.sql("SELECT COUNT(*) FROM FINANCIAL__ECONOMIC_ESSENTIALS.CYBERSYN.FINANCIAL_FRED_TIMESERIES").show()
# Out:
# ------------------------------------------------------
# |"VARIABLE_NAME"                                     |
# ------------------------------------------------------
# |30-Day AA Nonfinancial Commercial Paper Interes...  |
# |6-Month Treasury Bill Secondary Market Rate, Di...  |
# |New Privately-Owned Housing Units Completed: Un...  |
# |Other Loans and Leases: All Other Loans and Lea...  |
# |Nominal Emerging Market Economies U.S. Dollar I...  |
# |Other Securities: Non-MBS, Foreign-Related Inst...  |
# |Federal Funds Target Range - Upper Limit, Not s...  |
# |Liabilities and Capital: Liabilities: Deposits ...  |
# |1-Year Treasury Bill Secondary Market Rate, Dis...  |
# |Loans to Commercial Banks, Large Domestically C...  |
# ------------------------------------------------------
#
# --------------
# |"COUNT(*)"  |
# --------------
# |2307474     |
# --------------

# %%
# Now use Snowpark dataframe
snow_df_pce = (session.table("FINANCIAL__ECONOMIC_ESSENTIALS.CYBERSYN.FINANCIAL_FRED_TIMESERIES")
               .filter(col('VARIABLE_NAME') == 'Personal Consumption Expenditures: Chain-type Price Index, Seasonally adjusted, Monthly, Index 2017=100')
               .filter(col('DATE') >= '1972-01-01')
               .filter(month(col('DATE')) == 1)
               .orderBy(col('DATE'))) 
snow_df_pce.show()
# Out:
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"GEO_ID"     |"VARIABLE"                                          |"VARIABLE_NAME"                                     |"DATE"      |"VALUE"  |"UNIT"          |
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------
# |country/USA  |Personal_Consumption_Expenditures:_Chain-type_P...  |Personal Consumption Expenditures: Chain-type P...  |1972-01-31  |21.015   |Index 2017=100  |
# |country/USA  |Personal_Consumption_Expenditures:_Chain-type_P...  |Personal Consumption Expenditures: Chain-type P...  |1973-01-31  |21.695   |Index 2017=100  |
# |country/USA  |Personal_Consumption_Expenditures:_Chain-type_P...  |Personal Consumption Expenditures: Chain-type P...  |1974-01-31  |23.523   |Index 2017=100  |
# |country/USA  |Personal_Consumption_Expenditures:_Chain-type_P...  |Personal Consumption Expenditures: Chain-type P...  |1975-01-31  |26.132   |Index 2017=100  |
# |country/USA  |Personal_Consumption_Expenditures:_Chain-type_P...  |Personal Consumption Expenditures: Chain-type P...  |1976-01-31  |27.795   |Index 2017=100  |
# |country/USA  |Personal_Consumption_Expenditures:_Chain-type_P...  |Personal Consumption Expenditures: Chain-type P...  |1977-01-31  |29.263   |Index 2017=100  |
# |country/USA  |Personal_Consumption_Expenditures:_Chain-type_P...  |Personal Consumption Expenditures: Chain-type P...  |1978-01-31  |31.194   |Index 2017=100  |
# |country/USA  |Personal_Consumption_Expenditures:_Chain-type_P...  |Personal Consumption Expenditures: Chain-type P...  |1979-01-31  |33.597   |Index 2017=100  |
# |country/USA  |Personal_Consumption_Expenditures:_Chain-type_P...  |Personal Consumption Expenditures: Chain-type P...  |1980-01-31  |37.124   |Index 2017=100  |
# |country/USA  |Personal_Consumption_Expenditures:_Chain-type_P...  |Personal Consumption Expenditures: Chain-type P...  |1981-01-31  |41.011   |Index 2017=100  |
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Let Snowflake perform filtering using the Snowpark pushdown and display results in a Pandas dataframe
snow_df_pce = (session.table("FINANCIAL__ECONOMIC_ESSENTIALS.CYBERSYN.FINANCIAL_FRED_TIMESERIES")
               .filter(col('VARIABLE_NAME') == 'Personal Consumption Expenditures: Chain-type Price Index, Seasonally adjusted, Monthly, Index 2017=100')
               .filter(col('DATE') >= '1972-01-01')
               .filter(month(col('DATE')) == 1))
pd_df_pce_year = snow_df_pce.select(year(col('DATE')).alias('"Year"'), col('VALUE').alias('PCE')).orderBy(col('DATE')).to_pandas()
pd_df_pce_year
# Out:
#     Year      PCE
# 0   1972   21.015
# 1   1973   21.695
# 2   1974   23.523
# 3   1975   26.132
# 4   1976   27.795
# 5   1977   29.263
# 6   1978   31.194
# 7   1979   33.597
# 8   1980   37.124
# 9   1981   41.011
# 10  1982   43.853
# 11  1983   45.906
# 12  1984   47.564
# 13  1985   49.326
# 14  1986   51.084
# 15  1987   51.894
# 16  1988   53.828
# 17  1989   56.215
# 18  1990   58.553
# 19  1991   61.177
# 20  1992   62.638
# 21  1993   64.332
# 22  1994   65.604
# 23  1995   67.127
# 24  1996   68.452
# 25  1997   70.005
# 26  1998   70.736
# 27  1999   71.398
# 28  2000   72.961
# 29  2001   74.932
# 30  2002   75.431
# 31  2003   77.201
# 32  2004   78.909
# 33  2005   80.907
# 34  2006   83.534
# 35  2007   85.316
# 36  2008   88.206
# 37  2009   88.108
# 38  2010   90.136
# 39  2011   91.542
# 40  2012   93.894
# 41  2013   95.275
# 42  2014   96.614
# 43  2015   96.654
# 44  2016   97.496
# 45  2017   99.451
# 46  2018  101.199
# 47  2019  102.714
# 48  2020  104.458
# 49  2021  106.145
# 50  2022  112.829
# 51  2023  119.011
# 52  2024  121.870

# %%
# train model with PCE index

x = pd_df_pce_year["Year"].to_numpy().reshape(-1,1)
y = pd_df_pce_year["PCE"].to_numpy()

model = LinearRegression().fit(x, y)

# test model for 2022
predictYear = 2022
pce_pred = model.predict([[predictYear]])
# print the last 5 years
print (pd_df_pce_year.tail() )
# run the prediction for 2022
print ('Prediction for '+str(predictYear)+': '+ str(round(pce_pred[0],2)))
# Out:
#     Year      PCE
# 48  2020  104.458
# 49  2021  106.145
# 50  2022  112.829
# 51  2023  119.011
# 52  2024  121.870
# Prediction for 2022: 111.71

# %%
def predict_pce(predictYear: int) -> float:
   return model.predict([[predictYear]])[0].round(2).astype(float)

_ = session.udf.register(predict_pce,
                       return_type=FloatType(),
                       input_type=IntegerType(),
                       packages= ["pandas","scikit-learn"],
                       is_permanent=True,
                       name="predict_pce_udf",
                       replace=True,
                       stage_location="@udf_stage")
# Out:
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[67], line 4
#       1 def predict_pce(predictYear: int) -> float:
#       2    return model.predict([[predictYear]])[0].round(2).astype(float)
# ----> 4 _ = session.udf.register(predict_pce,
#       5                        return_type=FloatType(),
#       6                        input_type=IntegerType(),
#       7                        packages= ["pandas","scikit-learn"],
#       8                        is_permanent=True,
#       9                        name="predict_pce_udf",
#      10                        replace=True,
#      11                        stage_location="@udf_stage")
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\udf.py:603, in UDFRegistration.register(self, func, return_type, input_types, name, is_permanent, stage_location, imports, packages, replace, if_not_exists, parallel, max_batch_size, strict, secure, external_access_integrations, secrets, immutable, statement_params, source_code_display, **kwargs)
#     600 _from_pandas = kwargs.get("_from_pandas_udf_function", False)
#     602 # register udf
# --> 603 return self._do_register_udf(
#     604     func,
#     605     return_type,
#     606     input_types,
#     607     name,
#     608     stage_location,
#     609     imports,
#     610     packages,
#     611     replace,
#     612     if_not_exists,
#     613     parallel,
#     614     max_batch_size,
#     615     _from_pandas,
#     616     strict,
#     617     secure,
#     618     external_access_integrations=external_access_integrations,
#     619     secrets=secrets,
#     620     immutable=immutable,
#     621     statement_params=statement_params,
#     622     source_code_display=source_code_display,
#     623     api_call_source="UDFRegistration.register"
#     624     + ("[pandas_udf]" if _from_pandas else ""),
#     625     is_permanent=is_permanent,
#     626 )
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\udf.py:833, in UDFRegistration._do_register_udf(self, func, return_type, input_types, name, stage_location, imports, packages, replace, if_not_exists, parallel, max_batch_size, from_pandas_udf_function, strict, secure, external_access_integrations, secrets, immutable, statement_params, source_code_display, api_call_source, skip_upload_on_content_match, is_permanent)
#     820 if from_pandas_udf_function and not is_pandas_udf:
#     821     raise ValueError(
#     822         "You cannot create a non-vectorized UDF using pandas_udf(). "
#     823         "Use udf() instead."
#     824     )
#     826 (
#     827     handler,
#     828     code,
#     829     all_imports,
#     830     all_packages,
#     831     upload_file_stage_location,
#     832     custom_python_runtime_version_allowed,
# --> 833 ) = resolve_imports_and_packages(
#     834     self._session,
#     835     TempObjectType.FUNCTION,
#     836     func,
#     837     arg_names,
#     838     udf_name,
#     839     stage_location,
#     840     imports,
#     841     packages,
#     842     parallel,
#     843     is_pandas_udf,
#     844     is_dataframe_input,
#     845     max_batch_size,
#     846     statement_params=statement_params,
#     847     source_code_display=source_code_display,
#     848     skip_upload_on_content_match=skip_upload_on_content_match,
#     849     is_permanent=is_permanent,
#     850 )
#     852 if not custom_python_runtime_version_allowed:
#     853     check_python_runtime_version(
#     854         self._session._runtime_version_from_requirement
#     855     )
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\udf_utils.py:826, in resolve_imports_and_packages(session, object_type, func, arg_names, udf_name, stage_location, imports, packages, parallel, is_pandas_udf, is_dataframe_input, max_batch_size, statement_params, source_code_display, skip_upload_on_content_match, is_permanent, force_inline_code)
#     820 upload_and_import_stage = (
#     821     import_only_stage if is_permanent else session.get_session_stage()
#     822 )
#     824 # resolve packages
#     825 resolved_packages = (
# --> 826     session._resolve_packages(packages, include_pandas=is_pandas_udf)
#     827     if packages is not None
#     828     else session._resolve_packages(
#     829         [],
#     830         session._packages,
#     831         validate_package=False,
#     832         include_pandas=is_pandas_udf,
#     833     )
#     834 )
#     836 # resolve imports
#     837 if imports:
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\session.py:1300, in Session._resolve_packages(self, packages, existing_packages_dict, validate_package, include_pandas)
#    1295 result_dict = (
#    1296     existing_packages_dict if existing_packages_dict is not None else {}
#    1297 )
#    1299 # Retrieve list of dependencies that need to be added
# -> 1300 dependency_packages = self._get_dependency_packages(
#    1301     package_dict, validate_package, package_table, result_dict
#    1302 )
#    1304 # Add dependency packages
#    1305 for package in dependency_packages:
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\session.py:1128, in Session._get_dependency_packages(self, package_dict, validate_package, package_table, current_packages)
#    1118 def _get_dependency_packages(
#    1119     self,
#    1120     package_dict: Dict[str, Tuple[str, bool, pkg_resources.Requirement]],
#    (...)
#    1124 ) -> (List[Exception], Any):
#    1125     # Keep track of any package errors
#    1126     errors = []
# -> 1128     valid_packages = self._get_available_versions_for_packages(
#    1129         package_names=[v[0] for v in package_dict.values()],
#    1130         package_table_name=package_table,
#    1131         validate_package=validate_package,
#    1132     )
#    1134     unsupported_packages: List[str] = []
#    1135     for package, package_info in package_dict.items():
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\session.py:1578, in Session._get_available_versions_for_packages(self, package_names, package_table_name, validate_package)
#    1568 def _get_available_versions_for_packages(
#    1569     self,
#    1570     package_names: List[str],
#    1571     package_table_name: str,
#    1572     validate_package: bool = True,
#    1573 ) -> Dict[str, List[str]]:
#    1574     package_to_version_mapping = (
#    1575         {
#    1576             p[0]: json.loads(p[1])
#    1577             for p in self.table(package_table_name)
# -> 1578             .filter(
#    1579                 (col("language") == "python")
#    1580                 & (col("package_name").in_(package_names))
#    1581             )
#    1582             .group_by("package_name")
#    1583             .agg(array_agg("version"))
#    1584             ._internal_collect_with_tag()
#    1585         }
#    1586         if validate_package and len(package_names) > 0
#    1587         else None
#    1588     )
#    1589     return package_to_version_mapping
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\telemetry.py:184, in df_api_usage.<locals>.wrap(*args, **kwargs)
#     182 @functools.wraps(func)
#     183 def wrap(*args, **kwargs):
# --> 184     r = func(*args, **kwargs)
#     185     plan = r._select_statement or r._plan
#     186     # Some DataFrame APIs call other DataFrame APIs, so we need to remove the extra call
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\dataframe.py:1225, in DataFrame.filter(self, expr)
#    1204 """Filters rows based on the specified conditional expression (similar to WHERE
#    1205 in SQL).
#    1206
#    (...)
#    1221 :meth:`where` is an alias of :meth:`filter`.
#    1222 """
#    1223 if self._select_statement:
#    1224     return self._with_plan(
# -> 1225         self._select_statement.filter(
#    1226             _to_col_if_sql_expr(expr, "filter/where")._expression
#    1227         )
#    1228     )
#    1229 return self._with_plan(
#    1230     Filter(
#    1231         _to_col_if_sql_expr(expr, "filter/where")._expression,
#    1232         self._plan,
#    1233     )
#    1234 )
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\select_statement.py:696, in SelectStatement.filter(self, col)
#     692 def filter(self, col: Expression) -> "SelectStatement":
#     693     can_be_flattened = (
#     694         (not self.flatten_disabled)
#     695         and can_clause_dependent_columns_flatten(
# --> 696             derive_dependent_columns(col), self.column_states
#     697         )
#     698         and not has_data_generator_exp(self.projection)
#     699         and not (self.order_by and self.limit_ is not None)
#     700     )
#     701     if can_be_flattened:
#     702         new = copy(self)
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\select_statement.py:477, in SelectStatement.column_states(self)
#     475 if self._column_states is None:
#     476     if not self.projection and not self.has_clause:
# --> 477         self.column_states = self.from_.column_states
#     478     else:
#     479         super().column_states  # will assign value to self._column_states
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\select_statement.py:270, in Selectable.column_states(self)
#     265 """A dictionary that contains the column states of a query.
#     266 Refer to class ColumnStateDict.
#     267 """
#     268 if self._column_states is None:
#     269     self._column_states = initiate_column_states(
# --> 270         self.snowflake_plan.attributes,
#     271         self.analyzer,
#     272         self.df_aliased_col_name_to_real_col_name,
#     273     )
#     274 return self._column_states
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\functools.py:981, in cached_property.__get__(self, instance, owner)
#     979 val = cache.get(self.attrname, _NOT_FOUND)
#     980 if val is _NOT_FOUND:
# --> 981     val = self.func(instance)
#     982     try:
#     983         cache[self.attrname] = val
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\snowflake_plan.py:255, in SnowflakePlan.attributes(self)
#     253 @cached_property
#     254 def attributes(self) -> List[Attribute]:
# --> 255     output = analyze_attributes(self.schema_query, self.session)
#     256     # No simplifier case relies on this schema_query change to update SHOW TABLES to a nested sql friendly query.
#     257     if not self.schema_query or not self.session.sql_simplifier_enabled:
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\schema_utils.py:91, in analyze_attributes(sql, session)
#      88     session._run_query(sql)
#      89     return convert_result_meta_to_attribute(session._conn._cursor.description)
# ---> 91 return session._get_result_attributes(sql)
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\session.py:1976, in Session._get_result_attributes(self, query)
#    1975 def _get_result_attributes(self, query: str) -> List[Attribute]:
# -> 1976     return self._conn.get_result_attributes(query)
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\snowflake_plan.py:185, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     181 else:
#     182     ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     183         e
#     184     )
# --> 185     raise ne.with_traceback(tb) from None
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\snowflake_plan.py:116, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     114 def wrap(*args, **kwargs):
#     115     try:
# --> 116         return func(*args, **kwargs)
#     117     except snowflake.connector.errors.ProgrammingError as e:
#     118         query = getattr(e, "query", None)
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:226, in ServerConnection.get_result_attributes(self, query)
#     224 @SnowflakePlan.Decorator.wrap_exception
#     225 def get_result_attributes(self, query: str) -> List[Attribute]:
# --> 226     return convert_result_meta_to_attribute(run_new_describe(self._cursor, query))
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\schema_utils.py:144, in run_new_describe(cursor, query)
#     139 # ResultMetadataV2 may not currently be a type, depending on the connector
#     140 # version, so the argument types are pyright ignored
#     142 if hasattr(cursor, "_describe_internal"):
#     143     # Pyright does not perform narrowing here
# --> 144     return cursor._describe_internal(query)  # pyright: ignore
#     145 else:
#     146     return cursor.describe(query)
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\connector\cursor.py:1176, in SnowflakeCursor._describe_internal(self, *args, **kwargs)
#    1165 """Obtain the schema of the result without executing the query.
#    1166
#    1167 This function takes the same arguments as execute, please refer to that function
#    (...)
#    1173     The schema of the result, in the new result metadata format.
#    1174 """
#    1175 kwargs["_describe_only"] = kwargs["_is_internal"] = True
# -> 1176 self.execute(*args, **kwargs)
#    1177 return self._description
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\connector\cursor.py:1136, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements)
#    1132     is_integrity_error = (
#    1133         code == "100072"
#    1134     )  # NULL result in a non-nullable column
#    1135     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1136     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1137 return self
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\connector\errors.py:290, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     267 @staticmethod
#     268 def errorhandler_wrapper(
#     269     connection: SnowflakeConnection | None,
#    (...)
#     272     error_value: dict[str, Any],
#     273 ) -> None:
#     274     """Error handler wrapper that calls the errorhandler method.
#     275
#     276     Args:
#    (...)
#     287         exception to the first handler in that order.
#     288     """
# --> 290     handed_over = Error.hand_to_other_handler(
#     291         connection,
#     292         cursor,
#     293         error_class,
#     294         error_value,
#     295     )
#     296     if not handed_over:
#     297         raise Error.errorhandler_make_exception(
#     298             error_class,
#     299             error_value,
#     300         )
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\connector\errors.py:345, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     343 if cursor is not None:
#     344     cursor.messages.append((error_class, error_value))
# --> 345     cursor.errorhandler(connection, cursor, error_class, error_value)
#     346     return True
#     347 elif connection is not None:
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\connector\errors.py:221, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     219 errno = error_value.get("errno")
#     220 done_format_msg = error_value.get("done_format_msg")
# --> 221 raise error_class(
#     222     msg=error_value.get("msg"),
#     223     errno=None if errno is None else int(errno),
#     224     sqlstate=error_value.get("sqlstate"),
#     225     sfqid=error_value.get("sfqid"),
#     226     query=error_value.get("query"),
#     227     done_format_msg=(
#     228         None if done_format_msg is None else bool(done_format_msg)
#     229     ),
#     230     connection=connection,
#     231     cursor=cursor,
#     232 )
#
# SnowparkSQLException: (1304): 01b338b9-0103-909a-0002-1b360001c01a: 090105 (22000): Cannot perform SELECT. This session does not have a current database. Call 'USE DATABASE', or use a qualified name.

# %%
session.sql("select predict_pce_udf(2022)").show()
# Out:
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 session.sql("select predict_pce_udf(2022)").show()
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\telemetry.py:139, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
#     136 @functools.wraps(func)
#     137 def wrap(*args, **kwargs):
#     138     with args[0]._session.query_history() as query_history:
# --> 139         result = func(*args, **kwargs)
#     140     plan = args[0]._select_statement or args[0]._plan
#     141     api_calls = [
#     142         *plan.api_calls,
#     143         {TelemetryField.NAME.value: f"DataFrame.{func.__name__}"},
#     144     ]
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\dataframe.py:2891, in DataFrame.show(self, n, max_width, statement_params)
#    2872 @df_collect_api_telemetry
#    2873 def show(
#    2874     self,
#    (...)
#    2878     statement_params: Optional[Dict[str, str]] = None,
#    2879 ) -> None:
#    2880     """Evaluates this DataFrame and prints out the first ``n`` rows with the
#    2881     specified maximum number of characters per column.
#    2882
#    (...)
#    2888         statement_params: Dictionary of statement level parameters to be set while executing this action.
#    2889     """
#    2890     print(
# -> 2891         self._show_string(
#    2892             n,
#    2893             max_width,
#    2894             _statement_params=create_or_update_statement_params_with_query_tag(
#    2895                 statement_params or self._statement_params,
#    2896                 self._session.query_tag,
#    2897                 SKIP_LEVELS_TWO,
#    2898             ),
#    2899         )
#    2900     )
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\dataframe.py:3010, in DataFrame._show_string(self, n, max_width, **kwargs)
#    3006 query = self._plan.queries[-1].sql.strip().lower()
#    3008 if is_sql_select_statement(query):
#    3009     result, meta = self._session._conn.get_result_and_metadata(
# -> 3010         self.limit(n)._plan, **kwargs
#    3011     )
#    3012 else:
#    3013     res, meta = self._session._conn.get_result_and_metadata(
#    3014         self._plan, **kwargs
#    3015     )
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\telemetry.py:184, in df_api_usage.<locals>.wrap(*args, **kwargs)
#     182 @functools.wraps(func)
#     183 def wrap(*args, **kwargs):
# --> 184     r = func(*args, **kwargs)
#     185     plan = r._select_statement or r._plan
#     186     # Some DataFrame APIs call other DataFrame APIs, so we need to remove the extra call
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\dataframe.py:1740, in DataFrame.limit(self, n, offset)
#    1712 """Returns a new DataFrame that contains at most ``n`` rows from the current
#    1713 DataFrame, skipping ``offset`` rows from the beginning (similar to LIMIT and OFFSET in SQL).
#    1714
#    (...)
#    1737     <BLANKLINE>
#    1738 """
#    1739 if self._select_statement:
# -> 1740     return self._with_plan(self._select_statement.limit(n, offset=offset))
#    1741 return self._with_plan(Limit(Literal(n), Literal(offset), self._plan))
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\select_statement.py:810, in SelectStatement.limit(self, n, offset)
#     808 else:
#     809     new = copy(self)
# --> 810     new.from_ = self.from_.to_subqueryable()
#     811     new.limit_ = min(self.limit_, n) if self.limit_ else n
#     812     new.offset = offset or self.offset
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\select_statement.py:366, in SelectSQL.to_subqueryable(self)
#     359     return self
#     360 new = SelectSQL(
#     361     self._sql_query,
#     362     convert_to_select=True,
#     363     analyzer=self.analyzer,
#     364     params=self.query_params,
#     365 )
# --> 366 new.column_states = self.column_states
#     367 new._api_calls = self._api_calls
#     368 return new
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\select_statement.py:270, in Selectable.column_states(self)
#     265 """A dictionary that contains the column states of a query.
#     266 Refer to class ColumnStateDict.
#     267 """
#     268 if self._column_states is None:
#     269     self._column_states = initiate_column_states(
# --> 270         self.snowflake_plan.attributes,
#     271         self.analyzer,
#     272         self.df_aliased_col_name_to_real_col_name,
#     273     )
#     274 return self._column_states
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\functools.py:981, in cached_property.__get__(self, instance, owner)
#     979 val = cache.get(self.attrname, _NOT_FOUND)
#     980 if val is _NOT_FOUND:
# --> 981     val = self.func(instance)
#     982     try:
#     983         cache[self.attrname] = val
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\snowflake_plan.py:255, in SnowflakePlan.attributes(self)
#     253 @cached_property
#     254 def attributes(self) -> List[Attribute]:
# --> 255     output = analyze_attributes(self.schema_query, self.session)
#     256     # No simplifier case relies on this schema_query change to update SHOW TABLES to a nested sql friendly query.
#     257     if not self.schema_query or not self.session.sql_simplifier_enabled:
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\schema_utils.py:91, in analyze_attributes(sql, session)
#      88     session._run_query(sql)
#      89     return convert_result_meta_to_attribute(session._conn._cursor.description)
# ---> 91 return session._get_result_attributes(sql)
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\session.py:1976, in Session._get_result_attributes(self, query)
#    1975 def _get_result_attributes(self, query: str) -> List[Attribute]:
# -> 1976     return self._conn.get_result_attributes(query)
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\snowflake_plan.py:185, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     181 else:
#     182     ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     183         e
#     184     )
# --> 185     raise ne.with_traceback(tb) from None
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\snowflake_plan.py:116, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     114 def wrap(*args, **kwargs):
#     115     try:
# --> 116         return func(*args, **kwargs)
#     117     except snowflake.connector.errors.ProgrammingError as e:
#     118         query = getattr(e, "query", None)
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:226, in ServerConnection.get_result_attributes(self, query)
#     224 @SnowflakePlan.Decorator.wrap_exception
#     225 def get_result_attributes(self, query: str) -> List[Attribute]:
# --> 226     return convert_result_meta_to_attribute(run_new_describe(self._cursor, query))
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\snowpark\_internal\analyzer\schema_utils.py:144, in run_new_describe(cursor, query)
#     139 # ResultMetadataV2 may not currently be a type, depending on the connector
#     140 # version, so the argument types are pyright ignored
#     142 if hasattr(cursor, "_describe_internal"):
#     143     # Pyright does not perform narrowing here
# --> 144     return cursor._describe_internal(query)  # pyright: ignore
#     145 else:
#     146     return cursor.describe(query)
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\connector\cursor.py:1176, in SnowflakeCursor._describe_internal(self, *args, **kwargs)
#    1165 """Obtain the schema of the result without executing the query.
#    1166
#    1167 This function takes the same arguments as execute, please refer to that function
#    (...)
#    1173     The schema of the result, in the new result metadata format.
#    1174 """
#    1175 kwargs["_describe_only"] = kwargs["_is_internal"] = True
# -> 1176 self.execute(*args, **kwargs)
#    1177 return self._description
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\connector\cursor.py:1136, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements)
#    1132     is_integrity_error = (
#    1133         code == "100072"
#    1134     )  # NULL result in a non-nullable column
#    1135     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1136     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1137 return self
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\connector\errors.py:290, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     267 @staticmethod
#     268 def errorhandler_wrapper(
#     269     connection: SnowflakeConnection | None,
#    (...)
#     272     error_value: dict[str, Any],
#     273 ) -> None:
#     274     """Error handler wrapper that calls the errorhandler method.
#     275
#     276     Args:
#    (...)
#     287         exception to the first handler in that order.
#     288     """
# --> 290     handed_over = Error.hand_to_other_handler(
#     291         connection,
#     292         cursor,
#     293         error_class,
#     294         error_value,
#     295     )
#     296     if not handed_over:
#     297         raise Error.errorhandler_make_exception(
#     298             error_class,
#     299             error_value,
#     300         )
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\connector\errors.py:345, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     343 if cursor is not None:
#     344     cursor.messages.append((error_class, error_value))
# --> 345     cursor.errorhandler(connection, cursor, error_class, error_value)
#     346     return True
#     347 elif connection is not None:
#
# File c:\Users\EcHdnStoNe\AppData\Local\miniconda3\envs\snowpark\lib\site-packages\snowflake\connector\errors.py:221, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     219 errno = error_value.get("errno")
#     220 done_format_msg = error_value.get("done_format_msg")
# --> 221 raise error_class(
#     222     msg=error_value.get("msg"),
#     223     errno=None if errno is None else int(errno),
#     224     sqlstate=error_value.get("sqlstate"),
#     225     sfqid=error_value.get("sfqid"),
#     226     query=error_value.get("query"),
#     227     done_format_msg=(
#     228         None if done_format_msg is None else bool(done_format_msg)
#     229     ),
#     230     connection=connection,
#     231     cursor=cursor,
#     232 )
#
# SnowparkSQLException: (1304): 01b33895-0103-9028-0002-1b360001109a: 002140 (42601): SQL compilation error:
# Unknown function PREDICT_PCE_UDF
